# %% [markdown]
# <a href="https://colab.research.google.com/github/gmihaila/machine_learning_toolbox/blob/master/word_sentence_similarity_transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Word Similarity
#
# https://explosion.ai/blog/spacy-transformers

# %% [markdown]
# #### Install

# %%
# !pip install spacy-transformers

# !python -m spacy download en_trf_bertbaseuncased_lg
# !python -m spacy download de_trf_bertbasecased_lg
# !python -m spacy download en_trf_xlnetbasecased_lg
# !python -m spacy download en_trf_robertabase_lg
# !python -m spacy download en_trf_distilbertbaseuncased_lg
# Out:
# ...
#      |████████████████████████████████| 61kB 4.7MB/s
# ...
#      |████████████████████████████████| 10.4MB 20.9MB/s
# ...
#      |████████████████████████████████| 296kB 48.0MB/s
# ...
#      |████████████████████████████████| 61kB 8.9MB/s
# ...
#      |████████████████████████████████| 2.2MB 47.8MB/s
# ...
#      |████████████████████████████████| 3.7MB 29.7MB/s
# ...
#      |████████████████████████████████| 122kB 54.3MB/s
# ...
#      |████████████████████████████████| 1.0MB 53.3MB/s
# ...
#      |████████████████████████████████| 645kB 43.1MB/s
# ...
#      |████████████████████████████████| 860kB 50.1MB/s
# ...
#   Created wheel for spacy-transformers: filename=spacy_transformers-0.5.1-py2.py3-none-any.whl size=52837 sha256=4df829cb1e69a017b82e4b72f841d513e34f2dad7aa8c2d66009425b32786384
#   Stored in directory: /root/.cache/pip/wheels/29/c2/17/625a3d14da8cabe9781ab1648d489d1b41a8a81dc289e5af1f
# ...

# %% [markdown]
# #### Imports

# %%
## TF 2.0
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf

import spacy

import en_trf_bertbaseuncased_lg
import de_trf_bertbasecased_lg
import en_trf_xlnetbasecased_lg
import en_trf_robertabase_lg
import en_trf_distilbertbaseuncased_lg
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %% [markdown]
# #### Similarity

# %%
nlp = en_trf_bertbaseuncased_lg.load()

apple1 = nlp("Apple shares rose on the news.")
apple2 = nlp("Apple sold fewer iPhones this quarter.")
apple3 = nlp("Apple pie is delicious.")
print(apple1[0].similarity(apple2[0]))  # 0.73428553
print(apple1[0].similarity(apple3[0]))  # 0.43365782

print(apple3.similarity(apple1), apple1.similarity(apple2))
# Out:
# 0.7342855
# 0.43365782
# 0.5404962349940846 0.6986120688148408

# %% [markdown]
# #### Vector embedding

# %%
nlp("Apple shares rose on the news.").vector
# Out:
# array([ 6.09364223e+00, -1.86054897e+00,  7.17620313e-01,  4.29585409e+00,
#        -1.22607517e+00, -1.60135221e+00, -2.25767565e+00,  7.34396982e+00,
#        -1.96241438e+00,  5.38497090e-01, -4.89460856e-01, -3.79930377e+00,
#        -4.23491567e-01,  3.55041194e+00, -8.77407014e-01, -2.93929148e+00,
#        -7.95274854e-01,  1.71984935e+00,  7.25149930e-01,  4.34301168e-01,
#        -2.04220682e-01, -3.30724669e+00, -1.40650451e+00,  4.59810495e+00,
#         3.42912555e+00, -2.45903873e+00, -5.94232798e+00, -2.45301962e+00,
#        -2.83923101e+00, -2.78204679e+00,  1.87171662e+00,  1.64132667e+00,
#        -1.50057352e+00,  4.87869883e+00, -2.41017604e+00, -2.36963320e+00,
#        -4.15057302e-01, -3.92641282e+00, -4.52138615e+00,  3.81746817e+00,
#        -4.10323715e+00, -4.48688889e+00,  3.15781307e+00,  3.77954531e+00,
#        -2.07616854e+00, -2.68647838e+00, -8.58555794e-01,  2.62530118e-01,
# ...
